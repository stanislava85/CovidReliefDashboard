# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
group_data_by_boro = pd.read_csv("https://raw.githubusercontent.com/nychealth/coronavirus-data/master/totals/group-data-by-boro.csv")

# %%
group_data_by_boro
# Out:
#              group                subgroup  BK_CASE_COUNT  \
# 0      Boroughwide             Boroughwide       220971.0
# 1              Age                     0-4         5469.0
# 2              Age                    5-12        12037.0
# 3              Age                   13-17         8896.0
# 4              Age                    0-17            NaN
# 5              Age                   18-24        20167.0
# 6              Age                   25-34        41420.0
# 7              Age                   35-44        34305.0
# 8              Age                   45-54        30520.0
# 9              Age                   55-64        30278.0
# 10             Age                   65-74        21032.0
# 11             Age                     75+        16651.0
# 12  Race/ethnicity  Asian/Pacific-Islander        17426.0
# 13  Race/ethnicity  Black/African-American        46718.0
# 14  Race/ethnicity         Hispanic/Latino        35873.0
# ...

# %%
group_data_by_boro.drop([12,13,14,15,16,17], inplace=True)

# %%
group_data_by_boro
# Out:
#           group     subgroup  BK_CASE_COUNT  BK_HOSPITALIZED_COUNT  \
# 0   Boroughwide  Boroughwide       220971.0                30560.0
# 1           Age          0-4         5469.0                  243.0
# 2           Age         5-12        12037.0                  146.0
# 3           Age        13-17         8896.0                  154.0
# 4           Age         0-17            NaN                    NaN
# 5           Age        18-24        20167.0                  779.0
# 6           Age        25-34        41420.0                 2087.0
# 7           Age        35-44        34305.0                 2408.0
# 8           Age        45-54        30520.0                 3345.0
# 9           Age        55-64        30278.0                 5708.0
# 10          Age        65-74        21032.0                 6779.0
# 11          Age          75+        16651.0                 8911.0
#
#     BK_DEATH_COUNT  BK_CASE_RATE  BK_HOSPITALIZED_RATE  BK_DEATH_RATE  \
# ...

# %%
group_data_by_boro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   group                  12 non-null     object
#  1   subgroup               12 non-null     object
#  2   BK_CASE_COUNT          11 non-null     float64
#  3   BK_HOSPITALIZED_COUNT  11 non-null     float64
#  4   BK_DEATH_COUNT         9 non-null      float64
#  5   BK_CASE_RATE           11 non-null     float64
#  6   BK_HOSPITALIZED_RATE   11 non-null     float64
#  7   BK_DEATH_RATE          9 non-null      float64
#  8   BX_CASE_COUNT          11 non-null     float64
#  9   BX_HOSPITALIZED_COUNT  11 non-null     float64
#  10  BX_DEATH_COUNT         9 non-null      float64
#  11  BX_CASE_RATE           11 non-null     float64
#  12  BX_HOSPITALIZED_RATE   11 non-null     float64
#  13  BX_DEATH_RATE          9 non-null      float64
# ...

# %%
group_data_by_boro = group_data_by_boro.fillna((group_data_by_boro[group_data_by_boro['group']=='Age'][:3].sum()))

# %%
group_data_by_boro
# Out:
#           group     subgroup  BK_CASE_COUNT  BK_HOSPITALIZED_COUNT  \
# 0   Boroughwide  Boroughwide       220971.0                30560.0
# 1           Age          0-4         5469.0                  243.0
# 2           Age         5-12        12037.0                  146.0
# 3           Age        13-17         8896.0                  154.0
# 4           Age         0-17        26402.0                  543.0
# 5           Age        18-24        20167.0                  779.0
# 6           Age        25-34        41420.0                 2087.0
# 7           Age        35-44        34305.0                 2408.0
# 8           Age        45-54        30520.0                 3345.0
# 9           Age        55-64        30278.0                 5708.0
# 10          Age        65-74        21032.0                 6779.0
# 11          Age          75+        16651.0                 8911.0
#
#     BK_DEATH_COUNT  BK_CASE_RATE  BK_HOSPITALIZED_RATE  BK_DEATH_RATE  \
# ...

# %%
group_data_by_boro.drop([1,2,3],inplace=True)
group_data_by_boro
# Out:
#           group     subgroup  BK_CASE_COUNT  BK_HOSPITALIZED_COUNT  \
# 0   Boroughwide  Boroughwide       220971.0                30560.0
# 4           Age         0-17        26402.0                  543.0
# 5           Age        18-24        20167.0                  779.0
# 6           Age        25-34        41420.0                 2087.0
# 7           Age        35-44        34305.0                 2408.0
# 8           Age        45-54        30520.0                 3345.0
# 9           Age        55-64        30278.0                 5708.0
# 10          Age        65-74        21032.0                 6779.0
# 11          Age          75+        16651.0                 8911.0
#
#     BK_DEATH_COUNT  BK_CASE_RATE  BK_HOSPITALIZED_RATE  BK_DEATH_RATE  \
# 0           8230.0       8632.01               1193.80         321.50
# 4              9.0      14113.73                300.65           1.57
# 5             20.0       9703.71                374.83           9.62
# ...

# %%
group_data_by_boro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 11
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   group                  9 non-null      object
#  1   subgroup               9 non-null      object
#  2   BK_CASE_COUNT          9 non-null      float64
#  3   BK_HOSPITALIZED_COUNT  9 non-null      float64
#  4   BK_DEATH_COUNT         9 non-null      float64
#  5   BK_CASE_RATE           9 non-null      float64
#  6   BK_HOSPITALIZED_RATE   9 non-null      float64
#  7   BK_DEATH_RATE          9 non-null      float64
#  8   BX_CASE_COUNT          9 non-null      float64
#  9   BX_HOSPITALIZED_COUNT  9 non-null      float64
#  10  BX_DEATH_COUNT         9 non-null      float64
#  11  BX_CASE_RATE           9 non-null      float64
#  12  BX_HOSPITALIZED_RATE   9 non-null      float64
#  13  BX_DEATH_RATE          9 non-null      float64
# ...

# %%
for col in group_data_by_boro.columns:
    if "RATE" in col or "HOSPITALIZED_COUNT" in col:
        group_data_by_boro = group_data_by_boro.drop(col, axis=1)

# %%
group_data_by_boro
# Out:
#           group     subgroup  BK_CASE_COUNT  BK_DEATH_COUNT  BX_CASE_COUNT  \
# 0   Boroughwide  Boroughwide       220971.0          8230.0       145943.0
# 4           Age         0-17        26402.0             9.0        16408.0
# 5           Age        18-24        20167.0            20.0        13179.0
# 6           Age        25-34        41420.0            75.0        25812.0
# 7           Age        35-44        34305.0           171.0        22710.0
# 8           Age        45-54        30520.0           510.0        23162.0
# 9           Age        55-64        30278.0          1185.0        21971.0
# 10          Age        65-74        21032.0          2055.0        12763.0
# 11          Age          75+        16651.0          4205.0         9734.0
#
#     BX_DEATH_COUNT  MN_CASE_COUNT  MN_DEATH_COUNT  QN_CASE_COUNT  \
# 0           5429.0       104928.0          3625.0       220159.0
# 4              5.0         9199.0             2.0        22141.0
# ...

# %%
group_data_by_boro = group_data_by_boro[group_data_by_boro['group']=='Age']

# %%
group_data_by_boro
# Out:
#    group subgroup  BK_CASE_COUNT  BK_DEATH_COUNT  BX_CASE_COUNT  \
# 4    Age     0-17        26402.0             9.0        16408.0
# 5    Age    18-24        20167.0            20.0        13179.0
# 6    Age    25-34        41420.0            75.0        25812.0
# 7    Age    35-44        34305.0           171.0        22710.0
# 8    Age    45-54        30520.0           510.0        23162.0
# 9    Age    55-64        30278.0          1185.0        21971.0
# 10   Age    65-74        21032.0          2055.0        12763.0
# 11   Age      75+        16651.0          4205.0         9734.0
#
#     BX_DEATH_COUNT  MN_CASE_COUNT  MN_DEATH_COUNT  QN_CASE_COUNT  \
# 4              5.0         9199.0             2.0        22141.0
# 5              8.0        11146.0             3.0        18812.0
# 6             62.0        23528.0            21.0        39017.0
# 7            159.0        15473.0            61.0        36082.0
# ...
